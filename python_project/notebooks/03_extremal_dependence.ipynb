# %% [markdown]
# # 03 - Extremal dependence
#
# **Goal.** Estimate pairwise extremal dependence (chi, theta) for all station pairs, separately for winter and summer, and summarise against geographical distance.

# %%
import sys, pathlib
SRC = pathlib.Path('..').resolve() / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import station_pairs
import dependence_estimators

# %% [markdown]
# ## TODO
#
# - Decide tail level u (or grid of u).
# - Compute chi_hat and theta_hat for all pairs by season.
# - Run the block bootstrap once that estimator is implemented.
