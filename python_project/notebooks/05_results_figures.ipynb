# %% [markdown]
# # 05 - Results figures
#
# **Goal.** Produce the thesis figures from intermediate outputs of notebooks 01-03, save to `output/figures/`.

# %%
import sys, pathlib
SRC = pathlib.Path('..').resolve() / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import plotting

# %% [markdown]
# ## TODO
#
# - Generate the five figures listed in `empirical_design.tex` (section sec:emp-figures).
