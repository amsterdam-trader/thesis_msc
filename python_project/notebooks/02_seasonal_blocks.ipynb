# %% [markdown]
# # 02 - Seasonal blocks
#
# **Goal.** Apply the DJF winter-year convention, restrict to DJF and JJA, and construct seasonal block maxima of FX per station.

# %%
import sys, pathlib
SRC = pathlib.Path('..').resolve() / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import seasons
import extremes

# %% [markdown]
# ## TODO
#
# - Confirm block size (monthly within-season vs seasonal max).
# - Save the resulting wide-format block-maxima table to `output/intermediate/`.
