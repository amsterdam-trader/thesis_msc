# %% [markdown]
# # 01 - Data exploration
#
# **Goal.** Inspect the hourly KNMI parquet store and the station metadata. Document station availability, column names, types, and missingness. **Setup pass: no analysis yet.**

# %%
import sys, pathlib

SRC = pathlib.Path("..").resolve() / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import config
import data_loading
import station_metadata

config.HOURLY_PARQUET_DIR, config.STATION_METADATA_CSV
# Out:
# (WindowsPath('C:/Users/floris/Desktop/MSC/thesis_msc/data/yearly_aggregated_FH_FX'),
#  WindowsPath('C:/Users/floris/Desktop/MSC/thesis_msc/data/station_metadata.csv'))

# %% [markdown]
# ## TODO
#
# - Print one month and confirm column schema.
# - Plot station coverage as a year-by-station heatmap.
# - Decide on the SAMPLE_START_YEAR in config.py.
