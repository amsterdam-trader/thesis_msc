# %% [markdown]
# # 04 - Simulation design
#
# **Goal.** Methodological validation. Generate two seasonal dependence regimes on a synthetic station grid, run the same pipeline as the empirical analysis, and check whether the pipeline recovers the stronger winter dependence.

# %%
import sys, pathlib
SRC = pathlib.Path('..').resolve() / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import simulation
import dependence_estimators

# %% [markdown]
# ## TODO
#
# - Implement `simulation.simulate_block_maxima`.
# - Compare estimated chi-distance against the known ground truth.
